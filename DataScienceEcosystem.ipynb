# %% [markdown]
# ![image.png](attachment:55604964-a31a-43ca-b927-e2889c8bf18a.png)

# %% [markdown]
# ![image.png](attachment:1ce3743f-2939-4510-ac66-ad4943b939ec.png)

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![image.png](attachment:06d2512e-a54d-44c7-8714-5f59a01e977c.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![image.png](attachment:25164ae1-a03e-42df-a186-77ece4954714.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# ![image.png](attachment:92530caf-996e-41dd-9e5b-52f3ad9656f8.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPy
# 3. Matplotlib

# %% [markdown]
# ![image.png](attachment:5f0ba293-b310-40e5-a444-1128e5e1e92f.png)

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Jupyter Notebook   |
# | RStudio            |
# | Apache Spark       |

# %% [markdown]
# ![image.png](attachment:8c783ba6-54c3-427f-ad64-d552933c67f9.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![image.png](attachment:351a6729-4944-46ba-a473-1d50a1387cb1.png)

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %% [markdown]
# ![image.png](attachment:77e477e9-ba8e-4e85-a6bc-510398245551.png)

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours   = minutes / 60
hours
# Out:
# 3.3333333333333335

# %% [markdown]
# ![image.png](attachment:bca7db1f-c0d6-49d1-b76a-021cb993ccaf.png)

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries in Data Science
# - Create a table of Data Science Tools
# - Perform arithmetic expressions in Python

# %% [markdown]
# ![image.png](attachment:e9c6cf64-d1b1-4147-b5c4-318829eea3b1.png)

# %% [markdown]
# ## Author
# Faiqul Fikri
